# %% [markdown]
# DEEP DIVE: Micro-Challenge: The Guard Clause (Short-Circuiting)
#
# Didn't understand the question properly....

# %% [markdown]
# DEEP DIVE: Micro-Challenge: The Floating Point Trap

# %%
num1 = 0.1
num2 = 0.2

if (num1 + num2) == 0.3:
    print("True")
else:
    print("False")

# %% [markdown]
# DEEP DIVE: Micro-Challenge: The Truthiness Inspector

# %%
data = []

if (data == []) | (data == 0) | (data is None) | (data == "") | (data == {}) | (data == 0.0):

    print("Empty List")
else:
    print("Not Empty List")

# %% [markdown]
# DEEP DIVE: Micro-Challenge: The Ternary Packer

# %%
score = 85
status = "Pass" if score > 70 else "Fail"
print(status)
